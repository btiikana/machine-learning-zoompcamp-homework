# %%
import numpy as np
import pandas as pd

# %%
# DATA FRAMES

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
# Use DataFrame() function to view Data(List Of Lists) in tabular version
df = pd.DataFrame(data, columns=columns)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# Using DataFrame() function to view Data(Dictionary) in tabular view
dict_data = [
    {
        "Make": "Nissan",
        "Model": "Stanza",
        "Year": 1991,
        "Engine HP": 138.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "sedan",
        "MSRP": 2000
    },
    {
        "Make": "Hyundai",
        "Model": "Sonata",
        "Year": 2017,
        "Engine HP": None,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "Sedan",
        "MSRP": 27150
    },
    {
        "Make": "Lotus",
        "Model": "Elise",
        "Year": 2010,
        "Engine HP": 218.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "convertible",
        "MSRP": 54990
    },
    {
        "Make": "GMC",
        "Model": "Acadia",
        "Year": 2017,
        "Engine HP": 194.0,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "4dr SUV",
        "MSRP": 34450
    },
    {
        "Make": "Nissan",
        "Model": "Frontier",
        "Year": 2017,
        "Engine HP": 261.0,
        "Engine Cylinders": 6,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "Pickup",
        "MSRP": 32340
    }
]

# %%
dataf = pd.DataFrame(dict_data)
# Dictionary key pairs take care of the columns order!!!
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# USE head() function to check coupe of rows of the data
df.head(n=2) # n = number of rows
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %%
# Accessing specific columns, write variable.NameOfColumn
# e.g df.Make, df.Model
# OR
# variable.['NameOfColumn'], this very handy when column names have spaces between them
# e.f df['make']

# %%
# Example 1
dataf.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
# Example 2
dataf['Engine Cylinders']
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    6
# Name: Engine Cylinders, dtype: int64

# %%
# Example 2
dataf['Transmission Type']
# Out:
# 0       MANUAL
# 1    AUTOMATIC
# 2       MANUAL
# 3    AUTOMATIC
# 4       MANUAL
# Name: Transmission Type, dtype: object

# %%
#  FILTERING OUT WHAT COLUMNS YOU ONLY WANT TO SHOW
# Use df[['', '']], you nest a list of strings or column names in a list.

# %%
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# Example
dataf[['Make', 'Engine HP', 'MSRP']]
# Out:
#       Make  Engine HP   MSRP
# 0   Nissan      138.0   2000
# 1  Hyundai        NaN  27150
# 2    Lotus      218.0  54990
# 3      GMC      194.0  34450
# 4   Nissan      261.0  32340

# %%
# INSERTING NEW COLUMNS
# Name column with df['NewColumn'] and assign column with = [1, 2, 3, 4, 5]

# %%
# Example
dataf['ID'] = [1, 2, 3, 4, 5]

# %%
dataf['ID']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: ID, dtype: int64

# %%
# DELETING A COLUMN
# Use del operator
# e.g del df['Engine Cylinder']

# %%
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  ID
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
# Example
del dataf['ID']

# %%
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# INDEX
# Use index operator to check the index of the table
# e.g df.index
# if you want to check the index of any columns put column name first then index after
# e.g df.Model.index
# Access elements within the index use loc[index], this will show all the elements in the provided index
# e.g df.loc[0], loc = location
# Accessing multiple rows you need to nest a list of index inside loc list
# e.g df.loc[[0, 1, 2]]

# %%
# Example
dataf.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Example 2
dataf.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Example 3
dataf.loc[1]
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 1, dtype: object

# %%
# Example 4
# Multiple rows,
dataf.loc[[0,1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990

# %%
# REPLACING INDEX NUMBERS TO LETTERS
# e.g df.index['a', 'b'], here we change index = 0 to a and index 1 to b
# AFTER CHANGING INDEX YOU NEED TO USE THE NEW INDEX VALUE TO ACCESS ELEMENTS
# e.g df.index[['a', 'b']]
# ACCESSING POSITION, use iloc[] to get the position of the index in numbers always
# e.g df.iloc[[0, 1, 2]]
# *************************
# RESETING THE INDEX BACK TO DEFAULT
# Use reset_index() function
# e.g df.reset_index()
# GET RID OF INDEX IN COLUMN NAME
# Use drop=True inside reset_index()
# e.g df.reset_index(drop=True)
# NEED TO REASSIGN TO VARIABLE TO FULLY RESET
# dataframe = df.reset_index(drop=True)

# %%
dataf.index=['a', 'b', 'c', 'd', 'e']

# %%
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
# Example with loc
dataf.loc[['a', 'b']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan  Stanza  1991      138.0                 4            MANUAL
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150

# %%
# Example with iloc
dataf.iloc[[1, 2, 3]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
# d      GMC  Acadia  2017      194.0                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450

# %%
# Example with reset_index()
dataf.reset_index()
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
# Example with drop=True
dataf.reset_index(drop=True)
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
dataf
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
# Example with assigning new variable to FULLY RESET INDEX
data_frame = dataf.reset_index(drop=True)
data_frame
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
    # ELEMENT-WISE OPERATIONS

# %%
df['Engine HP'] * 2
# Out:
# 0    276.0
# 1      NaN
# 2    436.0
# 3    388.0
# 4    522.0
# Name: Engine HP, dtype: float64

# %%
df['Year'] >= 2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %%
df[
    df['Year'] >=2015
]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# FILTERING

# %%
df[
    df['Make'] == 'Nissan'
]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  Nissan    Stanza  1991      138.0                 4            MANUAL
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 4        Pickup  32340

# %%
df[
    (df['Make'] == 'Nissan') & (df['Year'] >= 2015)
]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 4        Pickup  32340

# %%
# STRING OPERATIONS

# %%
'machine learning zoomcamp'.replace(' ', '_')
# Out:
# 'machine_learning_zoomcamp'

# %%
df['Vehicle_Style'].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_').str.lower()

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %%
# SUMMARIZING OPERATIONS
# round() = round up

# %%
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.nunique()
# Out:
# Make                 4
# Model                5
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %%
# MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %%
# GROUPING

# %%
# SELECT 
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type

# %%
df.groupby('Transmission Type').MSRP.max()
# Out:
# Transmission Type
# AUTOMATIC    34450
# MANUAL       54990
# Name: MSRP, dtype: int64

# %%
# GETTING THE NUMPY ARRAYS

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'pickup',
# ...
